# %%
# %%writefile create_db.hql
#
# DROP DATABASE IF EXISTS stackoverflow CASCADE;
# CREATE DATABASE stackoverflow LOCATION '/user/jovyan/store/stackoverflow';
# Out:
# Overwriting create_db.hql

# %%
# %%writefile external_table.hql
#
# USE stackoverflow;
#
# ADD JAR /opt/cloudera/parcels/CDH/lib/hive/lib/hive-contrib.jar;
# ADD JAR /opt/cloudera/parcels/CDH/lib/hive/lib/hive-serde.jar;
#
# DROP TABLE IF EXISTS posts_sample_external;
#
# CREATE EXTERNAL TABLE posts_sample_external (
#     id INT,
#     post_type_id TINYINT,
#     date STRING,
#     owner_user_id INT,
#     parent_id INT,
#     score INT,
#     favorite_count INT,
#     tags STRING
# )
# ROW FORMAT SERDE 'org.apache.hadoop.hive.serde2.RegexSerDe' WITH SERDEPROPERTIES
# ('input.regex'='.*(?=\\bId=\"(\\d+)\")(?=.*\\bPostTypeId=\"(\\d+)\")(?=.*\\bCreationDate=\"(.{23})\")(?=.*\\bOwnerUserId=\"(\\d+)\")?(?=.*\\bParentId=\"(\\d+)\")?(?=.*\\bScore=\"(\\d+)\")(?=.*\\bFavoriteCount=\"(\\d+)\")?(?=.*\\bTags=\"(&lt\;.*gt\;)\")?.*')
# LOCATION '/data/stackexchange1000/posts';
# Out:
# Overwriting external_table.hql

# %%
# %%writefile sample.hql
#
# set hive.exec.dynamic.partition.mode=nonstrict;
#
# USE stackoverflow;
#
# DROP TABLE IF EXISTS posts_sample;
#
# CREATE TABLE posts_sample (
#     id INT,
#     post_type_id TINYINT,
#     owner_user_id INT,
#     parent_id INT,
#     score INT,
#     favorite_count INT,
#     tags ARRAY<STRING>
#
# )
# PARTITIONED BY (year STRING, month STRING)
# STORED AS SEQUENCEFILE;
#
# FROM posts_sample_external se
# INSERT OVERWRITE TABLE posts_sample PARTITION(year, month)
#     select se.id, se.post_type_id, se.owner_user_id, se.parent_id, se.score, se.favorite_count,split(se.tags,"&lt\;|&gt\;"),substr(se.date,0,4), substr(se.date,6,2)
#     WHERE se.id IS NOT NULL;
# Out:
# Overwriting sample.hql

# %%
# %%writefile count.hql
#
# INSERT OVERWRITE LOCAL DIRECTORY 'result' row format delimited fields terminated by '\t' stored as textfile
# SELECT year,concat(year, "-", month),count(*) FROM posts_sample group by year,month LIMIT 3;
# Out:
# Overwriting count.hql

# %%
# !hive -f create_db.hql
# !hive -f external_table.hql
# !hive -f sample.hql
# !hive -f count.hql
# !cat result/*|head -1
# Out:
# Logging initialized using configuration in jar:file:/usr/local/apache-hive-1.1.0-bin/lib/hive-common-1.1.0.jar!/hive-log4j.properties
# OK
# Time taken: 1.466 seconds
# OK
# Time taken: 0.137 seconds
#
# Logging initialized using configuration in jar:file:/usr/local/apache-hive-1.1.0-bin/lib/hive-common-1.1.0.jar!/hive-log4j.properties
# OK
# Time taken: 0.413 seconds
# Added [/opt/cloudera/parcels/CDH/lib/hive/lib/hive-contrib.jar] to class path
# Added resources: [/opt/cloudera/parcels/CDH/lib/hive/lib/hive-contrib.jar]
# Added [/opt/cloudera/parcels/CDH/lib/hive/lib/hive-serde.jar] to class path
# Added resources: [/opt/cloudera/parcels/CDH/lib/hive/lib/hive-serde.jar]
# OK
# Time taken: 0.044 seconds
# OK
# Time taken: 0.356 seconds
#
# Logging initialized using configuration in jar:file:/usr/local/apache-hive-1.1.0-bin/lib/hive-common-1.1.0.jar!/hive-log4j.properties
# OK
# Time taken: 0.394 seconds
# OK
# Time taken: 0.045 seconds
# OK
# Time taken: 0.378 seconds
# Query ID = jovyan_20171227114646_df34604d-e40e-41d8-bdea-7d6194fca3b6
# Total jobs = 3
# Launching Job 1 out of 3
# Number of reduce tasks is set to 0 since there's no reduce operator
# Starting Job = job_1514373326796_0010, Tracking URL = http://38ccdf094dbb:8088/proxy/application_1514373326796_0010/
# Kill Command = /opt/hadoop/bin/hadoop job  -kill job_1514373326796_0010
# Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 0
# 2017-12-27 11:46:17,048 Stage-1 map = 0%,  reduce = 0%
# 2017-12-27 11:46:32,470 Stage-1 map = 65%,  reduce = 0%, Cumulative CPU 13.47 sec
# 2017-12-27 11:46:38,622 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 19.16 sec
# MapReduce Total cumulative CPU time: 19 seconds 160 msec
# Ended Job = job_1514373326796_0010
# Stage-4 is selected by condition resolver.
# Stage-3 is filtered out by condition resolver.
# Stage-5 is filtered out by condition resolver.
# Moving data to: hdfs://localhost:9000/user/jovyan/store/stackoverflow/posts_sample/.hive-staging_hive_2017-12-27_11-46-10_457_7962891023829862039-1/-ext-10000
# Loading data to table stackoverflow.posts_sample partition (year=null, month=null)
# 	 Time taken for load dynamic partitions : 9181
# 	Loading partition {year=2008, month=11}
# 	Loading partition {year=2010, month=08}
# 	Loading partition {year=2011, month=12}
# 	Loading partition {year=2012, month=09}
# 	Loading partition {year=2015, month=05}
# 	Loading partition {year=2008, month=08}
# 	Loading partition {year=2009, month=02}
# 	Loading partition {year=2011, month=09}
# 	Loading partition {year=2012, month=03}
# 	Loading partition {year=2009, month=08}
# 	Loading partition {year=2010, month=02}
# 	Loading partition {year=2010, month=11}
# 	Loading partition {year=2014, month=04}
# 	Loading partition {year=2016, month=05}
# 	Loading partition {year=2012, month=12}
# 	Loading partition {year=2013, month=09}
# 	Loading partition {year=2010, month=12}
# 	Loading partition {year=2013, month=03}
# 	Loading partition {year=2011, month=11}
# 	Loading partition {year=2012, month=04}
# 	Loading partition {year=2016, month=06}
# 	Loading partition {year=2009, month=11}
# 	Loading partition {year=2009, month=03}
# 	Loading partition {year=2010, month=01}
# 	Loading partition {year=2013, month=04}
# 	Loading partition {year=2014, month=03}
# 	Loading partition {year=2009, month=09}
# 	Loading partition {year=2009, month=07}
# 	Loading partition {year=2011, month=01}
# 	Loading partition {year=2012, month=11}
# 	Loading partition {year=2010, month=07}
# 	Loading partition {year=2015, month=12}
# 	Loading partition {year=2013, month=08}
# 	Loading partition {year=2015, month=09}
# 	Loading partition {year=2008, month=12}
# 	Loading partition {year=2015, month=06}
# 	Loading partition {year=2014, month=05}
# 	Loading partition {year=2015, month=04}
# 	Loading partition {year=2012, month=07}
# 	Loading partition {year=2013, month=06}
# 	Loading partition {year=2015, month=10}
# 	Loading partition {year=2013, month=12}
# 	Loading partition {year=2014, month=11}
# 	Loading partition {year=2016, month=03}
# 	Loading partition {year=2010, month=04}
# 	Loading partition {year=2012, month=02}
# 	Loading partition {year=2010, month=10}
# 	Loading partition {year=2011, month=03}
# 	Loading partition {year=2010, month=09}
# 	Loading partition {year=2011, month=08}
# 	Loading partition {year=2013, month=01}
# 	Loading partition {year=2015, month=11}
# 	Loading partition {year=2015, month=08}
# 	Loading partition {year=2011, month=06}
# 	Loading partition {year=2013, month=07}
# 	Loading partition {year=2014, month=10}
# 	Loading partition {year=2016, month=08}
# 	Loading partition {year=2016, month=11}
# 	Loading partition {year=2014, month=01}
# 	Loading partition {year=2016, month=02}
# 	Loading partition {year=2010, month=05}
# 	Loading partition {year=2012, month=06}
# 	Loading partition {year=2014, month=07}
# 	Loading partition {year=2009, month=05}
# 	Loading partition {year=2014, month=02}
# 	Loading partition {year=2014, month=08}
# 	Loading partition {year=2015, month=01}
# 	Loading partition {year=2011, month=05}
# 	Loading partition {year=2010, month=06}
# 	Loading partition {year=2015, month=07}
# 	Loading partition {year=2016, month=12}
# 	Loading partition {year=2012, month=10}
# 	Loading partition {year=2012, month=05}
# 	Loading partition {year=2013, month=10}
# 	Loading partition {year=2015, month=02}
# 	Loading partition {year=2009, month=10}
# 	Loading partition {year=2016, month=01}
# 	Loading partition {year=2009, month=04}
# 	Loading partition {year=2016, month=10}
# 	Loading partition {year=2014, month=12}
# 	Loading partition {year=2016, month=07}
# 	Loading partition {year=2014, month=06}
# 	Loading partition {year=2014, month=09}
# 	Loading partition {year=2012, month=08}
# 	Loading partition {year=2013, month=11}
# 	Loading partition {year=2008, month=10}
# 	Loading partition {year=2011, month=10}
# 	Loading partition {year=2008, month=09}
# 	Loading partition {year=2015, month=03}
# 	Loading partition {year=2011, month=07}
# 	Loading partition {year=2013, month=02}
# 	Loading partition {year=2013, month=05}
# 	Loading partition {year=2011, month=04}
# 	Loading partition {year=2009, month=06}
# 	Loading partition {year=2010, month=03}
# 	Loading partition {year=2011, month=02}
# 	Loading partition {year=2012, month=01}
# 	Loading partition {year=2009, month=12}
# 	Loading partition {year=2016, month=04}
# 	Loading partition {year=2016, month=09}
# 	Loading partition {year=2009, month=01}
# 	 Time taken for adding to write entity : 13
# Partition stackoverflow.posts_sample{year=2008, month=08} stats: [numFiles=1, numRows=23, totalSize=996, rawDataSize=610]
# Partition stackoverflow.posts_sample{year=2008, month=09} stats: [numFiles=1, numRows=86, totalSize=3747, rawDataSize=2522]
# Partition stackoverflow.posts_sample{year=2008, month=10} stats: [numFiles=1, numRows=71, totalSize=3242, rawDataSize=2212]
# Partition stackoverflow.posts_sample{year=2008, month=11} stats: [numFiles=1, numRows=54, totalSize=2665, rawDataSize=1856]
# Partition stackoverflow.posts_sample{year=2008, month=12} stats: [numFiles=1, numRows=48, totalSize=2356, rawDataSize=1625]
# Partition stackoverflow.posts_sample{year=2009, month=01} stats: [numFiles=1, numRows=82, totalSize=3786, rawDataSize=2613]
# Partition stackoverflow.posts_sample{year=2009, month=02} stats: [numFiles=1, numRows=83, totalSize=3847, rawDataSize=2661]
# Partition stackoverflow.posts_sample{year=2009, month=03} stats: [numFiles=1, numRows=83, totalSize=4026, rawDataSize=2840]
# Partition stackoverflow.posts_sample{year=2009, month=04} stats: [numFiles=1, numRows=93, totalSize=4620, rawDataSize=3284]
# Partition stackoverflow.posts_sample{year=2009, month=05} stats: [numFiles=1, numRows=109, totalSize=5343, rawDataSize=3799]
# Partition stackoverflow.posts_sample{year=2009, month=06} stats: [numFiles=1, numRows=119, totalSize=5889, rawDataSize=4215]
# Partition stackoverflow.posts_sample{year=2009, month=07} stats: [numFiles=1, numRows=131, totalSize=6727, rawDataSize=4877]
# Partition stackoverflow.posts_sample{year=2009, month=08} stats: [numFiles=1, numRows=129, totalSize=6365, rawDataSize=4541]
# Partition stackoverflow.posts_sample{year=2009, month=09} stats: [numFiles=1, numRows=126, totalSize=6393, rawDataSize=4608]
# Partition stackoverflow.posts_sample{year=2009, month=10} stats: [numFiles=1, numRows=132, totalSize=6649, rawDataSize=4786]
# Partition stackoverflow.posts_sample{year=2009, month=11} stats: [numFiles=1, numRows=145, totalSize=7454, rawDataSize=5422]
# Partition stackoverflow.posts_sample{year=2009, month=12} stats: [numFiles=1, numRows=144, totalSize=7463, rawDataSize=5444]
# Partition stackoverflow.posts_sample{year=2010, month=01} stats: [numFiles=1, numRows=174, totalSize=8849, rawDataSize=6420]
# Partition stackoverflow.posts_sample{year=2010, month=02} stats: [numFiles=1, numRows=158, totalSize=8217, rawDataSize=5996]
# Partition stackoverflow.posts_sample{year=2010, month=03} stats: [numFiles=1, numRows=187, totalSize=9817, rawDataSize=7219]
# Partition stackoverflow.posts_sample{year=2010, month=04} stats: [numFiles=1, numRows=174, totalSize=9382, rawDataSize=6953]
# Partition stackoverflow.posts_sample{year=2010, month=05} stats: [numFiles=1, numRows=166, totalSize=8562, rawDataSize=6237]
# Partition stackoverflow.posts_sample{year=2010, month=06} stats: [numFiles=1, numRows=200, totalSize=10414, rawDataSize=7627]
# Partition stackoverflow.posts_sample{year=2010, month=07} stats: [numFiles=1, numRows=205, totalSize=11168, rawDataSize=8316]
# Partition stackoverflow.posts_sample{year=2010, month=08} stats: [numFiles=1, numRows=211, totalSize=11155, rawDataSize=8225]
# Partition stackoverflow.posts_sample{year=2010, month=09} stats: [numFiles=1, numRows=202, totalSize=10881, rawDataSize=8068]
# Partition stackoverflow.posts_sample{year=2010, month=10} stats: [numFiles=1, numRows=217, totalSize=11152, rawDataSize=8144]
# Partition stackoverflow.posts_sample{year=2010, month=11} stats: [numFiles=1, numRows=230, totalSize=12137, rawDataSize=8960]
# Partition stackoverflow.posts_sample{year=2010, month=12} stats: [numFiles=1, numRows=236, totalSize=12359, rawDataSize=9084]
# Partition stackoverflow.posts_sample{year=2011, month=01} stats: [numFiles=1, numRows=273, totalSize=14559, rawDataSize=10783]
# Partition stackoverflow.posts_sample{year=2011, month=02} stats: [numFiles=1, numRows=269, totalSize=14385, rawDataSize=10661]
# Partition stackoverflow.posts_sample{year=2011, month=03} stats: [numFiles=1, numRows=346, totalSize=18093, rawDataSize=13348]
# Partition stackoverflow.posts_sample{year=2011, month=04} stats: [numFiles=1, numRows=318, totalSize=16590, rawDataSize=12209]
# Partition stackoverflow.posts_sample{year=2011, month=05} stats: [numFiles=1, numRows=324, totalSize=17363, rawDataSize=12904]
# Partition stackoverflow.posts_sample{year=2011, month=06} stats: [numFiles=1, numRows=339, totalSize=17860, rawDataSize=13206]
# Partition stackoverflow.posts_sample{year=2011, month=07} stats: [numFiles=1, numRows=329, totalSize=17400, rawDataSize=12876]
# Partition stackoverflow.posts_sample{year=2011, month=08} stats: [numFiles=1, numRows=353, totalSize=18747, rawDataSize=13891]
# Partition stackoverflow.posts_sample{year=2011, month=09} stats: [numFiles=1, numRows=342, totalSize=18419, rawDataSize=13706]
# Partition stackoverflow.posts_sample{year=2011, month=10} stats: [numFiles=1, numRows=322, totalSize=17189, rawDataSize=12756]
# Partition stackoverflow.posts_sample{year=2011, month=11} stats: [numFiles=1, numRows=355, totalSize=19113, rawDataSize=14231]
# Partition stackoverflow.posts_sample{year=2011, month=12} stats: [numFiles=1, numRows=341, totalSize=17921, rawDataSize=13241]
# Partition stackoverflow.posts_sample{year=2012, month=01} stats: [numFiles=1, numRows=370, totalSize=19409, rawDataSize=14332]
# Partition stackoverflow.posts_sample{year=2012, month=02} stats: [numFiles=1, numRows=406, totalSize=22177, rawDataSize=16612]
# Partition stackoverflow.posts_sample{year=2012, month=03} stats: [numFiles=1, numRows=424, totalSize=22844, rawDataSize=17025]
# Partition stackoverflow.posts_sample{year=2012, month=04} stats: [numFiles=1, numRows=407, totalSize=22782, rawDataSize=17184]
# Partition stackoverflow.posts_sample{year=2012, month=05} stats: [numFiles=1, numRows=416, totalSize=23150, rawDataSize=17435]
# Partition stackoverflow.posts_sample{year=2012, month=06} stats: [numFiles=1, numRows=408, totalSize=22359, rawDataSize=16768]
# Partition stackoverflow.posts_sample{year=2012, month=07} stats: [numFiles=1, numRows=438, totalSize=24964, rawDataSize=18943]
# Partition stackoverflow.posts_sample{year=2012, month=08} stats: [numFiles=1, numRows=438, totalSize=23946, rawDataSize=17945]
# Partition stackoverflow.posts_sample{year=2012, month=09} stats: [numFiles=1, numRows=391, totalSize=21521, rawDataSize=16151]
# Partition stackoverflow.posts_sample{year=2012, month=10} stats: [numFiles=1, numRows=453, totalSize=25372, rawDataSize=19156]
# Partition stackoverflow.posts_sample{year=2012, month=11} stats: [numFiles=1, numRows=428, totalSize=23663, rawDataSize=17792]
# Partition stackoverflow.posts_sample{year=2012, month=12} stats: [numFiles=1, numRows=404, totalSize=21735, rawDataSize=16196]
# Partition stackoverflow.posts_sample{year=2013, month=01} stats: [numFiles=1, numRows=471, totalSize=25453, rawDataSize=19003]
# Partition stackoverflow.posts_sample{year=2013, month=02} stats: [numFiles=1, numRows=465, totalSize=26013, rawDataSize=19641]
# Partition stackoverflow.posts_sample{year=2013, month=03} stats: [numFiles=1, numRows=509, totalSize=28151, rawDataSize=21187]
# Partition stackoverflow.posts_sample{year=2013, month=04} stats: [numFiles=1, numRows=513, totalSize=29065, rawDataSize=22029]
# Partition stackoverflow.posts_sample{year=2013, month=05} stats: [numFiles=1, numRows=509, totalSize=28195, rawDataSize=21231]
# Partition stackoverflow.posts_sample{year=2013, month=06} stats: [numFiles=1, numRows=460, totalSize=25852, rawDataSize=19545]
# Partition stackoverflow.posts_sample{year=2013, month=07} stats: [numFiles=1, numRows=530, totalSize=29953, rawDataSize=22696]
# Partition stackoverflow.posts_sample{year=2013, month=08} stats: [numFiles=1, numRows=518, totalSize=29183, rawDataSize=22082]
# Partition stackoverflow.posts_sample{year=2013, month=09} stats: [numFiles=1, numRows=490, totalSize=27750, rawDataSize=21033]
# Partition stackoverflow.posts_sample{year=2013, month=10} stats: [numFiles=1, numRows=554, totalSize=30428, rawDataSize=22859]
# Partition stackoverflow.posts_sample{year=2013, month=11} stats: [numFiles=1, numRows=530, totalSize=29600, rawDataSize=22343]
# Partition stackoverflow.posts_sample{year=2013, month=12} stats: [numFiles=1, numRows=497, totalSize=27948, rawDataSize=21140]
# Partition stackoverflow.posts_sample{year=2014, month=01} stats: [numFiles=1, numRows=576, totalSize=32821, rawDataSize=24946]
# Partition stackoverflow.posts_sample{year=2014, month=02} stats: [numFiles=1, numRows=569, totalSize=32167, rawDataSize=24383]
# Partition stackoverflow.posts_sample{year=2014, month=03} stats: [numFiles=1, numRows=601, totalSize=33842, rawDataSize=25622]
# Partition stackoverflow.posts_sample{year=2014, month=04} stats: [numFiles=1, numRows=575, totalSize=32491, rawDataSize=24629]
# Partition stackoverflow.posts_sample{year=2014, month=05} stats: [numFiles=1, numRows=518, totalSize=28743, rawDataSize=21642]
# Partition stackoverflow.posts_sample{year=2014, month=06} stats: [numFiles=1, numRows=468, totalSize=27093, rawDataSize=20662]
# Partition stackoverflow.posts_sample{year=2014, month=07} stats: [numFiles=1, numRows=507, totalSize=28730, rawDataSize=21772]
# Partition stackoverflow.posts_sample{year=2014, month=08} stats: [numFiles=1, numRows=481, totalSize=27074, rawDataSize=20474]
# Partition stackoverflow.posts_sample{year=2014, month=09} stats: [numFiles=1, numRows=472, totalSize=26680, rawDataSize=20197]
# Partition stackoverflow.posts_sample{year=2014, month=10} stats: [numFiles=1, numRows=504, totalSize=28876, rawDataSize=21957]
# Partition stackoverflow.posts_sample{year=2014, month=11} stats: [numFiles=1, numRows=475, totalSize=27274, rawDataSize=20752]
# Partition stackoverflow.posts_sample{year=2014, month=12} stats: [numFiles=1, numRows=463, totalSize=26972, rawDataSize=20606]
# Partition stackoverflow.posts_sample{year=2015, month=01} stats: [numFiles=1, numRows=474, totalSize=26598, rawDataSize=20109]
# Partition stackoverflow.posts_sample{year=2015, month=02} stats: [numFiles=1, numRows=484, totalSize=27545, rawDataSize=20906]
# Partition stackoverflow.posts_sample{year=2015, month=03} stats: [numFiles=1, numRows=541, totalSize=30688, rawDataSize=23268]
# Partition stackoverflow.posts_sample{year=2015, month=04} stats: [numFiles=1, numRows=550, totalSize=30523, rawDataSize=23006]
# Partition stackoverflow.posts_sample{year=2015, month=05} stats: [numFiles=1, numRows=546, totalSize=30988, rawDataSize=23503]
# Partition stackoverflow.posts_sample{year=2015, month=06} stats: [numFiles=1, numRows=539, totalSize=30885, rawDataSize=23491]
# Partition stackoverflow.posts_sample{year=2015, month=07} stats: [numFiles=1, numRows=561, totalSize=32581, rawDataSize=24900]
# Partition stackoverflow.posts_sample{year=2015, month=08} stats: [numFiles=1, numRows=535, totalSize=30837, rawDataSize=23495]
# Partition stackoverflow.posts_sample{year=2015, month=09} stats: [numFiles=1, numRows=510, totalSize=29176, rawDataSize=22179]
# Partition stackoverflow.posts_sample{year=2015, month=10} stats: [numFiles=1, numRows=524, totalSize=30847, rawDataSize=23648]
# Partition stackoverflow.posts_sample{year=2015, month=11} stats: [numFiles=1, numRows=501, totalSize=28578, rawDataSize=21718]
# Partition stackoverflow.posts_sample{year=2015, month=12} stats: [numFiles=1, numRows=512, totalSize=29115, rawDataSize=22092]
# Partition stackoverflow.posts_sample{year=2016, month=01} stats: [numFiles=1, numRows=552, totalSize=32136, rawDataSize=24573]
# Partition stackoverflow.posts_sample{year=2016, month=02} stats: [numFiles=1, numRows=558, totalSize=32324, rawDataSize=24683]
# Partition stackoverflow.posts_sample{year=2016, month=03} stats: [numFiles=1, numRows=619, totalSize=35845, rawDataSize=27371]
# Partition stackoverflow.posts_sample{year=2016, month=04} stats: [numFiles=1, numRows=583, totalSize=33565, rawDataSize=25579]
# Partition stackoverflow.posts_sample{year=2016, month=05} stats: [numFiles=1, numRows=576, totalSize=32638, rawDataSize=24763]
# Partition stackoverflow.posts_sample{year=2016, month=06} stats: [numFiles=1, numRows=560, totalSize=32179, rawDataSize=24512]
# Partition stackoverflow.posts_sample{year=2016, month=07} stats: [numFiles=1, numRows=533, totalSize=31134, rawDataSize=23818]
# Partition stackoverflow.posts_sample{year=2016, month=08} stats: [numFiles=1, numRows=539, totalSize=31368, rawDataSize=23974]
# Partition stackoverflow.posts_sample{year=2016, month=09} stats: [numFiles=1, numRows=517, totalSize=29871, rawDataSize=22783]
# Partition stackoverflow.posts_sample{year=2016, month=10} stats: [numFiles=1, numRows=517, totalSize=30231, rawDataSize=23143]
# Partition stackoverflow.posts_sample{year=2016, month=11} stats: [numFiles=1, numRows=509, totalSize=30054, rawDataSize=23070]
# Partition stackoverflow.posts_sample{year=2016, month=12} stats: [numFiles=1, numRows=177, totalSize=10243, rawDataSize=7775]
# MapReduce Jobs Launched:
# Stage-Stage-1: Map: 1   Cumulative CPU: 20.0 sec   HDFS Read: 60005218 HDFS Write: 2104390 SUCCESS
# Total MapReduce CPU Time Spent: 20 seconds 0 msec
# OK
# Time taken: 58.03 seconds
#
# Logging initialized using configuration in jar:file:/usr/local/apache-hive-1.1.0-bin/lib/hive-common-1.1.0.jar!/hive-log4j.properties
# Query ID = jovyan_20171227114747_e493b7ed-a388-4c0c-a00b-ee09d880b4c6
# Total jobs = 2
# Launching Job 1 out of 2
# Number of reduce tasks not specified. Estimated from input data size: 1
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1514373326796_0011, Tracking URL = http://38ccdf094dbb:8088/proxy/application_1514373326796_0011/
# Kill Command = /opt/hadoop/bin/hadoop job  -kill job_1514373326796_0011
# Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 1
# 2017-12-27 11:47:23,003 Stage-1 map = 0%,  reduce = 0%
# 2017-12-27 11:47:28,250 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 3.77 sec
# 2017-12-27 11:47:33,457 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 5.56 sec
# MapReduce Total cumulative CPU time: 5 seconds 560 msec
# Ended Job = job_1514373326796_0011
# Launching Job 2 out of 2
# Number of reduce tasks determined at compile time: 1
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1514373326796_0012, Tracking URL = http://38ccdf094dbb:8088/proxy/application_1514373326796_0012/
# Kill Command = /opt/hadoop/bin/hadoop job  -kill job_1514373326796_0012
# Hadoop job information for Stage-2: number of mappers: 1; number of reducers: 1
# 2017-12-27 11:47:44,660 Stage-2 map = 0%,  reduce = 0%
# 2017-12-27 11:47:48,800 Stage-2 map = 100%,  reduce = 0%, Cumulative CPU 0.83 sec
# 2017-12-27 11:47:53,968 Stage-2 map = 100%,  reduce = 100%, Cumulative CPU 2.44 sec
# MapReduce Total cumulative CPU time: 2 seconds 440 msec
# Ended Job = job_1514373326796_0012
# Copying data to local directory result
# Copying data to local directory result
# MapReduce Jobs Launched:
# Stage-Stage-1: Map: 1  Reduce: 1   Cumulative CPU: 5.56 sec   HDFS Read: 2149859 HDFS Write: 189 SUCCESS
# Stage-Stage-2: Map: 1  Reduce: 1   Cumulative CPU: 2.44 sec   HDFS Read: 4655 HDFS Write: 48 SUCCESS
# Total MapReduce CPU Time Spent: 8 seconds 0 msec
# OK
# Time taken: 40.143 seconds
# 2008	2008-10	71

# %%
# %%writefile rank.hql
# SELECT ps2016.tag, ps2016.popularity, ps2009.popularity,
#     rank() OVER(ORDER BY ps2009.popularity desc) r2009 from
# (SELECT tag, count(*) popularity from posts_sample ps
#     LATERAL VIEW EXPLODE(tags) ps as tag
#     WHERE post_type_id=1 and year = '2016'
#     GROUP BY tag) ps2016 LEFT JOIN
# (SELECT tag, count(*) popularity from posts_sample
#     LATERAL VIEW EXPLODE(tags) posts_sample as tag
#     WHERE post_type_id=1 and year = '2009'
#     GROUP BY tag) ps2009 on ps2016.tag = ps2009.tag ORDER BY ps2016.popularity DESC LIMIT 10;
# Out:
# Overwriting rank.hql

# %%
# !hive -f rank.hql
# Out:
# Logging initialized using configuration in jar:file:/usr/local/apache-hive-1.1.0-bin/lib/hive-common-1.1.0.jar!/hive-log4j.properties
# Query ID = jovyan_20171227153333_3c250ef2-5c61-4e87-93bc-f5a23b1697ef
# Total jobs = 6
# Launching Job 1 out of 6
# Number of reduce tasks not specified. Estimated from input data size: 1
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1514373326796_0060, Tracking URL = http://38ccdf094dbb:8088/proxy/application_1514373326796_0060/
# Kill Command = /opt/hadoop/bin/hadoop job  -kill job_1514373326796_0060
# Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 1
# 2017-12-27 15:33:20,753 Stage-1 map = 0%,  reduce = 0%
# 2017-12-27 15:33:25,009 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 3.1 sec
# 2017-12-27 15:33:31,278 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 4.98 sec
# MapReduce Total cumulative CPU time: 4 seconds 980 msec
# Ended Job = job_1514373326796_0060
# Launching Job 2 out of 6
# Number of reduce tasks not specified. Estimated from input data size: 1
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1514373326796_0061, Tracking URL = http://38ccdf094dbb:8088/proxy/application_1514373326796_0061/
# Kill Command = /opt/hadoop/bin/hadoop job  -kill job_1514373326796_0061
# Hadoop job information for Stage-5: number of mappers: 1; number of reducers: 1
# 2017-12-27 15:33:43,326 Stage-5 map = 0%,  reduce = 0%
# 2017-12-27 15:33:49,553 Stage-5 map = 100%,  reduce = 0%, Cumulative CPU 2.91 sec
# 2017-12-27 15:33:54,712 Stage-5 map = 100%,  reduce = 100%, Cumulative CPU 4.77 sec
# MapReduce Total cumulative CPU time: 4 seconds 770 msec
# Ended Job = job_1514373326796_0061
# Stage-8 is selected by condition resolver.
# Stage-2 is filtered out by condition resolver.
# Execution log at: /tmp/jovyan/jovyan_20171227153333_3c250ef2-5c61-4e87-93bc-f5a23b1697ef.log
# 2017-12-27 03:34:01	Starting to launch local task to process map join;	maximum memory = 477626368
# 2017-12-27 03:34:02	Dump the side-table for tag: 1 with group count: 555 into file: file:/tmp/jovyan/89127295-45a4-4506-91ca-d13415e598a6/hive_2017-12-27_15-33-11_771_429401301447514432-1/-local-10007/HashTable-Stage-6/MapJoin-mapfile01--.hashtable
# 2017-12-27 03:34:02	Uploaded 1 File to: file:/tmp/jovyan/89127295-45a4-4506-91ca-d13415e598a6/hive_2017-12-27_15-33-11_771_429401301447514432-1/-local-10007/HashTable-Stage-6/MapJoin-mapfile01--.hashtable (16275 bytes)
# 2017-12-27 03:34:02	End of local task; Time Taken: 0.838 sec.
# Execution completed successfully
# MapredLocal task succeeded
# Launching Job 4 out of 6
# Number of reduce tasks is set to 0 since there's no reduce operator
# Starting Job = job_1514373326796_0062, Tracking URL = http://38ccdf094dbb:8088/proxy/application_1514373326796_0062/
# Kill Command = /opt/hadoop/bin/hadoop job  -kill job_1514373326796_0062
# Hadoop job information for Stage-6: number of mappers: 1; number of reducers: 0
# 2017-12-27 15:34:09,427 Stage-6 map = 0%,  reduce = 0%
# 2017-12-27 15:34:14,639 Stage-6 map = 100%,  reduce = 0%, Cumulative CPU 2.14 sec
# MapReduce Total cumulative CPU time: 2 seconds 140 msec
# Ended Job = job_1514373326796_0062
# Launching Job 5 out of 6
# Number of reduce tasks not specified. Estimated from input data size: 1
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1514373326796_0063, Tracking URL = http://38ccdf094dbb:8088/proxy/application_1514373326796_0063/
# Kill Command = /opt/hadoop/bin/hadoop job  -kill job_1514373326796_0063
# Hadoop job information for Stage-3: number of mappers: 1; number of reducers: 1
# 2017-12-27 15:34:28,011 Stage-3 map = 0%,  reduce = 0%
# 2017-12-27 15:34:32,140 Stage-3 map = 100%,  reduce = 0%, Cumulative CPU 1.51 sec
# 2017-12-27 15:34:37,301 Stage-3 map = 100%,  reduce = 100%, Cumulative CPU 3.62 sec
# MapReduce Total cumulative CPU time: 3 seconds 620 msec
# Ended Job = job_1514373326796_0063
# Launching Job 6 out of 6
# Number of reduce tasks determined at compile time: 1
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1514373326796_0064, Tracking URL = http://38ccdf094dbb:8088/proxy/application_1514373326796_0064/
# Kill Command = /opt/hadoop/bin/hadoop job  -kill job_1514373326796_0064
# Hadoop job information for Stage-4: number of mappers: 1; number of reducers: 1
# 2017-12-27 15:34:48,408 Stage-4 map = 0%,  reduce = 0%
# 2017-12-27 15:34:53,598 Stage-4 map = 100%,  reduce = 0%, Cumulative CPU 1.24 sec
# 2017-12-27 15:34:57,737 Stage-4 map = 100%,  reduce = 100%, Cumulative CPU 2.95 sec
# MapReduce Total cumulative CPU time: 2 seconds 950 msec
# Ended Job = job_1514373326796_0064
# MapReduce Jobs Launched:
# Stage-Stage-1: Map: 1  Reduce: 1   Cumulative CPU: 4.98 sec   HDFS Read: 376598 HDFS Write: 74759 SUCCESS
# Stage-Stage-5: Map: 1  Reduce: 1   Cumulative CPU: 4.77 sec   HDFS Read: 83496 HDFS Write: 15618 SUCCESS
# Stage-Stage-6: Map: 1   Cumulative CPU: 2.14 sec   HDFS Read: 78584 HDFS Write: 75067 SUCCESS
# Stage-Stage-3: Map: 1  Reduce: 1   Cumulative CPU: 3.62 sec   HDFS Read: 81076 HDFS Write: 82778 SUCCESS
# Stage-Stage-4: Map: 1  Reduce: 1   Cumulative CPU: 2.95 sec   HDFS Read: 87734 HDFS Write: 140 SUCCESS
# Total MapReduce CPU Time Spent: 18 seconds 460 msec
# OK
# 	1422	1422	1
# c#	45	45	2
# java	28	28	3
# asp.net	26	26	4
# php	24	24	5
# .net	20	20	6
# jquery	20	20	6
# javascript	19	19	8
# python	19	19	8
# sql	17	17	10
# Time taken: 108.196 seconds, Fetched: 10 row(s)
